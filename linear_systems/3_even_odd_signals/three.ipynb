# %% [markdown]
# ## Question 1
# Q.1: Problem 1.5-3(a) and (b) of the textbook.
# 1.5-3
# 1.5-4
# (a) Determine even and odd components of the signal $x(t) = e^{−2t} u(t)$.

# %% [markdown]
# $x(t) = \frac{x(t) + x(-t)}{2} + \frac{x(t) - x(-t)}{2}$
#
#
#
#
# $\text{Even part:} \quad \frac{e^{2t} u(-t) + e^{-2t} u(t)}{2}$
#
# $\text{Odd part:} \quad \frac{-e^{2t} u(-t) + e^{-2t} u(t)}{2}$
#
# $x(t) =  \quad \frac{e^{2t} u(-t) + e^{-2t} u(t)}{2} + \quad \frac{-e^{2t} u(-t) + e^{-2t} u(t)}{2}$

# %% [markdown]
# (b) Show that the energy of x(t) is the sum of energies of its odd and even components found in part (a).

# %% [markdown]
# the energy of the signal is the square of the magnitude of the signal at each point in time.
#
# EVEN_ENERGY $ = \int_{-\infty}^{0} \left(\frac{e^{2t}}{2}\right)^2 dt + \int_{0}^{\infty} \left(\frac{e^{-2t}}{2}\right)^2 dt = \frac{1}{8}$
#
# ODD_ENERGY $ = \int_{-\infty}^{0} \left(\frac{-e^{2t}}{2}\right)^2 dt + \int_{0}^{\infty} \left(\frac{e^{-2t}}{2}\right)^2 dt = \frac{1}{8}$
#
# x(t)_ENERGY  = $E = \int_{0}^{\infty} |e^{-2t}|^2 dt = \int_{0}^{\infty} e^{-4t} dt = \frac{1}{4}$
#
# $\textbf{EVENENERGY} + \textbf{ODDENERGY} =  1/8 + 1/8 = 1/4$

# %% [markdown]
# # Question 2
# ### 1.5-4 of the textbook
#
# ### a)
# If x e (t) and x o (t) are even and the odd
# components of a real signal x(t), then show
# that show that the integral
#
# $\int_{-\infty}^{\infty} x_{e}(t) x_{o}(t) dt = 0$
#
# Even definition : $f(t) = f(-t)$
#
# odd definition  : $g(t) = -g(-t)$
#
# the product of $f(-t)$ and $-g(-t)$ is $-f(-t)g(-t)$ which is an odd function.
#
# We also know that the area under the curve from -a to a in an odd function must always be zero because the area on the left side of the y axis will be equal and opposite of that of the right side of the y axis
#
#
# $\int_{-\infty}^{\infty} x_{e}(t) x_{o}(t) dt = 0$
#
#
#
# ### b)
#
# show that
#
# $\int_{-\infty}^{\infty} x(t) dt = \int_{-\infty}^{\infty} x_{e}(t) dt$
#
# This is true because the odd component is zero from the same bounds as previously shown. Therefore, the only nonzero term in
#
# $ \int_{-\infty}^{\infty} x_{e}(t) dt + \int_{-\infty}^{\infty} x_{o}(t) dt $
#
# is
#
# $ \int_{-\infty}^{\infty} x_{e}(t) dt$

# %% [markdown]
# ## Question 3
#
# 1.5-7 part a from the textbook

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function x(t) as defined in the image provided by the user
def x(t):
    if t >= -1 and t < 0:
        return t + 1
    elif t >= 0 and t <= 1:
        return 1 - t
    else:
        return 0

# Generating time points
t = np.linspace(-2, 2, 1000)
# Applying the function to time points
x_t = np.array([x(ti) for ti in t])

# Plotting the function x(t)
plt.figure(figsize=(10, 4))
plt.plot(t, x_t, label='x(t)')
plt.xlabel('t')
plt.ylabel('x(t)')
plt.title('Signal x(t)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# \begin{align*}
# \text{Original signal:} \quad & x(t) \\
# \text{Amplitude scaling:} \quad & v(t) = 3 \cdot x(t) \\
# \text{Time scaling:} \quad & v(t) =  (-\frac{1}{2} \cdot t) \\
# \text{Time shifting:} \quad & v(t) = (t + 1) \\
# \end{align*}

# %%
# Define the transformed signal v(t) = 3x(-(1/2)(t + 1))
def v(t):
    # Apply the transformation to the time variable before passing it to the x(t) function
    transformed_t = -0.5 * (t + 1)
    return 3 * x(transformed_t)

# Apply the function to each time point using list comprehension
v_values = [v(ti) for ti in t]

# Plot the graph
plt.plot(t, v_values, label='v(t) = 3x(-(1/2)(t + 1))')
plt.title('Graph of v(t)')
plt.xlabel('t')
plt.ylabel('v(t)')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Question 4
# Figure P1.5-13  part a

# %% [markdown]
# # Question 5
# 1.7-1 of the textbook a and d
#
# a)
#
# $\frac{dy(t)}{dt} + 2y(t) = x^2(t)$
#
# This equation is $\textbf{linear}$ because neither the  y or y' term are not raised to any power or multiplied by eachother $
#
# d)
#
# $\frac{dy(t)}{dt} + y^2(t) = x(t)$
#
# This equation is $\textbf{not linear}$ because it includes a term with the dependent variable $y(t)$ raised to the second power $y^2(t)$

# %% [markdown]
# # Question 6
# 1.7-1 of the textbook a and d
#
# this is the same as the last question, maybe a typo in the homework ?

# %% [markdown]
# # Question 7
# 1.7-16 For the systems described by the following
# equations, with the input x(t) and output y(t),
# determine which are invertible and which are
# noninvertible. For the invertible systems, find
# the input–output relationship of the inverse
# system.

# %% [markdown]
# # Question 8

# %% [markdown]
# 1.8-1
# For the circuit depicted in Fig. P1.8-1, find the
# differential equations relating outputs y 1 (t) and
# y 2 (t) to the input x(t).

# %% [markdown]
# # Question 9
# Problem 1.11-1 of the textbook.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the time interval and number of points
t = np.linspace(-2*np.pi, 2*np.pi, 1000)

# Define the original function x(t) with the unit step function behavior included
def u(t):
    return np.where(t >= np.pi, 1, 0)

def x(t):
    return (2 - t * np.cos(2*np.pi*t)) * u(t)

# Calculate the odd portion xo(t)
def xo(t):
    return 0.5 * (x(t) - x(-t))

# Plot xo(t)
plt.figure(figsize=(10, 6))
plt.plot(t, xo(t), label='$x_o(t)$')
plt.title('Odd Portion $x_o(t)$ of the Function $x(t)$')
plt.xlabel('$t$')
plt.ylabel('$x_o(t)$')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Question 10
# Problem 1.11-2 of the textbook.

# %%
# Define the time interval and spacing
t = np.arange(-2, 2, 0.002)  

# Define the original function x(t) with the updated parameters
def u(t):
    return np.where(t >= 0.5, 1, 0)

def x(t):
    return (2 - t/2 * np.cos(4*np.pi*t)) * u(t)

# Calculate the even portion xe(t)
def xe(t):
    return 0.5 * (x(t) + x(-t))

# Plot xe(t)
plt.figure(figsize=(10, 6))
plt.plot(t, xe(t), label='$x_e(t)$')
plt.title('Even Portion $x_e(t)$ of the Function $x(t)$')
plt.xlabel('$t$')
plt.ylabel('$x_e(t)$')
plt.grid(True)
plt.legend()
plt.show()
