# %% [markdown]
# ### Problem 2:
# Let $A$ and $B$ be two events. If $A$ and $B$ are independent events, then:
#
# $$P(A \cap B) = P(A) \cdot P(B)$$
#
# Given that $P(A) = 0.5$ and $P(A \cap B^c) = 0.4$, where $B^c$ denotes the complement of event $B$.
#
# We want to find the value of $P(B)$ that will make events $A$ and $B$ independent.
#
# Substitute the given values into the formula for independence and solve for $P(B)$:
#
# $$P(A \cap B) = P(A) \cdot P(B)$$
# $$0.4 = 0.5 \cdot P(B)$$
# $$P(B) = \frac{0.4}{0.5}$$
# $$P(B) = 0.8$$
#
# Therefore, for $A$ and $B$ to be independent, $P(B)$ should be $0.8$.
#
#
# ### Problem 6:
# Let:
# - $P(asthma) = 0.056$, representing the proportion of the population with asthma.
# - $P(asthma\_attack | asthma) = 0.027$, representing the probability of an asthmatic having an asthma attack on a given day.
#
# To find the probability that a randomly chosen person has an asthma attack, we use the total probability formula:
#
# $$P(asthma\_attack) = P(asthma) \cdot P(asthma\_attack | asthma)$$
# $$P(asthma\_attack) = 0.056 \cdot 0.027$$
# $$P(asthma\_attack) = 0.001512$$
#
# Therefore, the probability that a randomly chosen person has an asthma attack on that day is $0.001512$.
#
#
# ### Problem 10:
# Given:
# - $P(engineering) = 0.3$ is the probability that a student majors in engineering.
# - $P(club\_sports) = 0.2$ is the probability that a student plays club sports.
# - $P(engineering \cap club\_sports) = 0.1$ is the probability that a student both majors in engineering and plays club sports.
#
# a. The probability that the student is majoring in engineering is simply $P(engineering) = 0.3$.
#
# b. The probability that the student plays club sports is $P(club\_sports) = 0.2$.
#
# c. To find the probability that a student plays club sports given that they are majoring in engineering, we use the conditional probability formula:
#
# $$P(club\_sports | engineering) = \frac{P(engineering \cap club\_sports)}{P(engineering)}$$
# $$P(club\_sports | engineering) = \frac{0.1}{0.3}$$
# $$P(club\_sports | engineering) ≈ 0.3333$$
#
# Therefore:
# - a. $P(engineering) = 0.3$
# - b. $P(club\_sports) = 0.2$
# - c. $P(club\_sports | engineering) ≈ 0.3333$
#
#
# ### Problem 1:
# Given that the student plays club sports, what is the probability that the student is majoring in engineering?
#
# To solve this problem, we can use the formula for conditional probability:
#
# $$
# P(\text{Majoring in Engineering | Playing Club Sports}) = \frac{P(\text{Majoring in Engineering and Playing Club Sports})}{P(\text{Playing Club Sports})}
# $$
#
# ### Problem 2:
# Given that the student is majoring in engineering, what is the probability that the student does not play club sports?
#
# To solve this problem, we can use the formula for conditional probability:
#
# $$
# P(\text{Not playing Club Sports | Majoring in Engineering}) = \frac{P(\text{Majoring in Engineering and Not Playing Club Sports})}{P(\text{Majoring in Engineering})}
# $$
#
# ### Problem 3:
# Given that the student plays club sports, what is the probability that the student is not majoring in engineering?
#
# To solve this problem, we can use the formula for conditional probability:
#
# $$
# P(\text{Not Majoring in Engineering | Playing Club Sports}) = \frac{P(\text{Not Majoring in Engineering and Playing Club Sports})}{P(\text{Playing Club Sports})}
# $$
#
# ### Problem 4:
# Lorez and Felipe each fire one shot at a target. Lorez has probability 0.5 of hitting the target, and Felipe has probability 0.3. The shots are independent.
#
# a. Find the probability that the target is hit.
#
# The probability that the target is hit by at least one shot can be calculated as $1 - P(\text{Both Miss the Target})$.
#
# b. Find the probability that the target is hit by exactly one shot.
#
# The probability that the target is hit by exactly one shot can be calculated as $P(\text{Exactly One Hit})$.
#
# c. Given that the target was hit by exactly one shot, find the probability that Lorez hit the target.
#
# The probability that Lorez hit the target given that the target was hit by exactly one shot can be calculated using the formula for conditional probability.
#
# ### Problem 5:
# A car dealer sold 750 automobiles last year. The following table categorizes the cars sold by size and color and presents the number of cars in each category. A car is to be chosen at random from the 750 for which the owner will win a lifetime of free oil.
#
# To calculate the probability of winning a lifetime of free oil when choosing a car randomly, we need more information on the distribution of sizes and colors of the cars sold. Once we have that data, we can calculate the probability accordingly.
#
#
# To solve these problems in Python and calculate the probabilities, we can use basic probability formulas. Let's start by defining the data for the first problem:
#
# | Color   | White | Black | Red  | Grey  |
# |---------|-------|-------|------|-------|
# | Small   | 102   | 71    | 33   | 134   |
# | Midsize | 86    | 63    | 36   | 105   |
# | Large   | 26    | 32    | 22   | 40    |
#
# Now, let's calculate the probabilities for the given scenarios:
#
# a. If the car is small, what is the probability that it is black?
#
# $$
# P(\text{Black} | \text{Small}) = \frac{P(\text{Black and Small})}{P(\text{Small})}
# $$
#
# b. If the car is white, what is the probability that it is midsize?
#
# $$
# P(\text{Midsize} | \text{White}) = \frac{P(\text{White and Midsize})}{P(\text{White})}
# $$
#
# c. If the car is large, what is the probability that it is red?
#
# $$
# P(\text{Red} | \text{Large}) = \frac{P(\text{Red and Large})}{P(\text{Large})}
# $$
#
# d. If the car is red, what is the probability that it is large?
#
# $$
# P(\text{Large} | \text{Red}) = \frac{P(\text{Red and Large})}{P(\text{Red})}
# $$
#
# e. If the car is not small, what is the probability that it is not grey?
#
# Let's calculate these probabilities using Python.
#
#
# To solve these problems with Python, we can use probabilities and conditional probabilities formulas. Below is the Python code to solve each problem along with the documentation in markdown format for each part.
#
# ### Problem 1:
# 1. The probability that the customer has filed a claim?
# ```python
# # Probability formula: P(Claim) = Number of customers who filed a claim / Total number of customers
# probability_claim = number_of_claim_customers / total_customers
# print(f"The probability that the customer has filed a claim: {probability_claim}")
# ```
#
# 2. Given that the customer has filed a claim, what is the probability that the customer is a good risk?
#
# ```python
# # Probability formula: P(Good Risk | Claim) = P(Good Risk and Claim) / P(Claim)
# probability_good_risk_given_claim = probability_good_risk_and_claim / probability_claim
# print(f"The probability that the customer is a good risk given that they have filed a claim: {probability_good_risk_given_claim}")
# ```
#
# ### Problem 2:
# 1. Find P(4)
#
# ```python
# # Probability of first component being defective
# P_A = 300 / 1000
# print(f"P(4): {P_A}")
# ```
#
# 2. Find P(B|A)
#
# ```python
# # Probability of the second component being defective given the first one is defective
# P_B_given_A = (299 / 999)
# print(f"P(B|A): {P_B_given_A}")
# ```
#
# 3. Find P(4 ∩ B)
#
# ```python
# # Probability of both components being defective
# P_A_and_B = (300/1000) * (299/999)
# print(f"P(4 ∩ B): {P_A_and_B}")
# ```
#
# 4. Find P(A° ∩ B)
#
# ```python
# # Probability of at least one component being defective
# P_A_union_B = 1 - (700/1000 * 699/999)
# print(f"P(A° ∩ B): {P_A_union_B}")
# ```
#
# 5. Find P(B)
#
# ```python
# # Probability of the second component being defective
# P_B = 300/1000
# print(f"P(B): {P_B}")
# ```
#
# 6. Find P(A|B)
#
# ```python
# # Probability of the first component being defective given the second one is defective
# P_A_given_B = (300/1000) * (299/999) / (300/1000)
# print(f"P(A|B): {P_A_given_B}")
# ```
#
# 7. Are A and B independent? Is it reasonable to treat 4 and B as though they were independent? Explain.
#
# ```python
# # Check if A and B are independent
# if P_A * P_B == P_A_and_B:
#     print("A and B are independent")
# else:
#     print("A and B are not independent")
# ```
#
# ### Problem 3:
# 1. What is the probability that the parcel was delivered by express delivery?
#
# ```python
# # Probability of express delivery
# P_express_delivery = 0.25
# print(f"The probability that the parcel was delivered by express delivery: {P_express_delivery}")
# ```
#
# These Python codes can be run in a Jupyter notebook to compute the probabilities for each scenario in the problems provided.
#
#
# ## Problem 1:
#
# ### a. Given that we know that 60% of packages that were shipped express arrived the next day, what is the probability that a package was shipped express and arrived the next day?
#
# Let:
# - A be the event that the package was shipped express.
# - B be the event that the package arrived the next day.
#
# We are given:
# $P(B|A) = 0.60$ (Probability of the package arriving the next day given that it was shipped express)
# $P(A) = ?$ (Probability of the package being shipped express)
# $P(A \cap B) = ?$ (Probability of the package being shipped express and arriving the next day)
#
# Using the conditional probability formula:
# $$P(A \cap B) = P(A) \cdot P(B|A)$$
# We can substitute the values given to find the probability that a package was shipped express and arrived the next day.
#
# ### b. What is the probability that it arrived the next day?
#
# Given that 60% of packages that were shipped express arrived the next day, we can directly say $P(B) = 0.60$.
#
# ### c. Given that the package arrived the next day, what is the probability that it was sent express?
#
# Let's use Bayes' Theorem to find this probability:
#
# $$P(A|B) = \frac{P(A) \cdot P(B|A)}{P(B)}$$
#
# We already know the values for $P(B|A)$ and $P(B)$, and we can calculate $P(A)$ from the given information to find $P(A|B)$.
#
# ## Problem 2:
#
# ### Given the quality-control details of the plastic bottle production line, we have the following probabilities:
# - Probability of a bottle having a flaw: $0.0002$
# - Probability of a flawed bottle failing inspection: $0.995$
# - Probability of a flawless bottle passing inspection: $0.9$
#
# ### a. If a bottle fails inspection, what is the probability that it has a flaw?
#
# Let:
# - C be the event that the bottle has a flaw.
# - D be the event that the bottle fails inspection.
#
# We are interested in finding $P(C|D)$, which can be calculated using Bayes' Theorem:
# $$P(C|D) = \frac{P(C) \cdot P(D|C)}{P(D)}$$
#
# ### b. Interpretation of the answer:
# - This would help determine whether most bottles that fail inspection have flaws or not.
#
# ### c. If a bottle passes inspection, what is the probability that it does not have a flaw?
#
# We are interested in finding the complementary event, i.e., if a bottle passes inspection, what is the probability that it does not have a flaw. This can be calculated as $1 - P(C|D')$ where $D'$ is the event of passing inspection.
#
#
# Sure! Here are the solutions to the problems using Python:
#
# ### Problem 1: Calculate the sum of two numbers
# ```python
# # Function to calculate the sum of two numbers
# def sum_numbers(a, b):
#     """
#     Calculate the sum of two numbers.
#
#     Parameters:
#     a (int): First number
#     b (int): Second number
#
#     Returns:
#     int: Sum of the two numbers
#     """
#     return a + b
#
# # Test the function with example numbers
# num1 = 5
# num2 = 3
# result = sum_numbers(num1, num2)
# print(f"The sum of {num1} and {num2} is: {result}")
# ```
#
# ### Problem 2: Calculate the product of two numbers
# ```python
# # Function to calculate the product of two numbers
# def multiply_numbers(a, b):
#     """
#     Calculate the product of two numbers.
#
#     Parameters:
#     a (int): First number
#     b (int): Second number
#
#     Returns:
#     int: Product of the two numbers
#     """
#     return a * b
#
# # Test the function with example numbers
# num1 = 5
# num2 = 3
# result = multiply_numbers(num1, num2)
# print(f"The product of {num1} and {num2} is: {result}")
# ```
#
# ### Problem 3: Check if a number is prime
# ```python
# from sympy import isprime
#
# # Function to check if a number is prime
# def check_prime(num):
#     """
#     Check if a number is prime.
#
#     Parameters:
#     num (int): Number to check
#
#     Returns:
#     bool: True if the number is prime, False otherwise
#     """
#     return isprime(num)
#
# # Test the function with an example number
# num = 17
# is_prime = check_prime(num)
# if is_prime:
#     print(f"{num} is a prime number")
# else:
#     print(f"{num} is not a prime number")
# ```
#
# You can run these code snippets in a Python environment to see the results. Let me know if you need further assistance!

# %% [markdown]
# #### Data Representation in Computer Systems
#
# - **Positional Numbering Systems**
#     - Representing numbers based on their positional value.
#
# - **Converting Between Bases**
#     - Converting numbers between different base systems.
#
# - **Signed Integer Representation**
#     - Representing integers with sign bits.
#
# - **Floating-Point Representation**
#     - Representing numbers with a fractional part.#### Problems with Floating-Point Numbers
#
# Floating-point numbers can lead to precision errors due to their binary representation in computer systems.
#
# #### Character Codes
#
# - **Binary-Coded Decimal (BCD)**: Encodes decimal numbers using binary code.
# - **EBCDIC**: Extended Binary Coded Decimal Interchange Code used by IBM mainframes.
# - **ASCII**: American Standard Code for Information Interchange is a widely used character encoding standard.
# - **Unicode**: A universal character encoding standard that supports multiple languages and symbols.
#
# #### Error Detection and Correction
#
# - **Cyclic Redundancy Check (CRC)**: A method of error detection in data transmission.
# - **Hamming Codes**: Error-correcting codes that can detect and correct single-bit errors.
# - **Reed-Solomon**: A forward error correction code used in digital communication and storage.
#
# #### Boolean Algebra and Digital Logic
#
# #### Introduction
#
# Boolean algebra and digital logic form the foundation for designing and analyzing digital circuits.
#
# #### Boolean Algebra
#
# - **Boolean Expressions**: Mathematical expressions using logical operators like AND, OR, and NOT.
# - **Boolean Identities**: Fundamental rules for simplifying and manipulating Boolean expressions.
# - **Simplification of Boolean Expressions**: Techniques to reduce the complexity of Boolean expressions.
# - **Complements**: Operations for obtaining the complement of a Boolean variable.
# - **Representing Boolean Functions**: Expressing logical functions using Boolean algebra.
#
# #### Logic Gates
#
# - **Symbols for Logic Gates**: Representation of basic logical operations such as AND, OR, and NOT.
# - **Universal Gates**: Gates that can be used to implement any other logic gate.
# - **Multiple Input Gates**: Gates that accept multiple inputs to perform logical operations.
#
# #### Karnaugh Maps
#
# - **Introduction**: A graphical method for simplifying Boolean expressions.
# - **Description of Kmaps and Terminology**: Understanding the structure and terminology of Karnaugh maps.
# - **Kmap Simplification for Two, Three, and Four Variables**: Techniques for simplifying Boolean functions using Karnaugh maps.
# - **Don't Care Conditions**: Handling conditions that are not relevant to the desired output.
# - **Summary**: Summarizing the advantages of using Karnaugh maps for logic simplification.#### Components
# - Digital Circuits and Boolean Algebra
# - Integrated Circuits
# - From Problem Description to Circuit
#
# #### Combinational Circuits
# - Basic Concepts
# - Typical Combinational Circuits
#
# #### Sequential Circuits
# - Basic Concepts
# - Clocks
# - Flip-Flops
# - Finite-State Machines
# - Examples of Sequential Circuits
# - Convolutional Coding and Viterbi Detection
#
# #### Designing Circuits
#
# #### MARIE: An Introduction to a Simple Computer
# - Introduction
# - CPU Basics and Organization
# - The Registers
# - The ALU
# - The Control Unit
# - The Bus
# - Clocks
# - Input/Output Subsystem
# - Memory Organization and Addressing
# - Interrupts
# - MARIE Architecture#### **Registers and Buses**
# Registers hold data for the CPU to process. Buses are pathways that transfer data between components.
#
# #### **Instruction Set Architecture**
# Describes the set of instructions a CPU can execute.
#
# #### **Register Transfer Notation**
#
# #### **Instruction Processing**
# Describes how instructions are fetched, decoded, and executed by the CPU.
#
# #### **The Fetch–Decode–Execute Cycle**
# Basic cycle where CPU fetches instruction, decodes it, and executes it.
#
# #### **Interrupts and the Instruction Cycle**
# Interruptions to the normal instruction cycle.
#
# #### **MARIE’s I/O**
# Input/output operations in the MARIE architecture.
#
# #### **A Simple Program**
#
# #### **A Discussion on Assemblers**
# Assemblers convert assembly language to machine code.
#
# #### **What Do Assemblers Do?**
# Assemblers translate human-readable assembly code to machine code.
#
# #### **Why Use Assembly Language?**
# Benefits of using low-level assembly language.
#
# #### **Extending Our Instruction Set**
#
# #### **A Discussion on Decoding**
# Comparison between hardwired and microprogrammed control for instruction decoding.
#
# #### **Machine Control**
#
# #### **Hardwired Control**
#
# #### **Microprogrammed Control**
#
# #### **Real-World Examples of Computer Architectures**
# Overview of Intel and MIPS architectures.
#
# #### **Intel Architectures**
#
# #### **MIPS Architectures**
#
# #### **A Closer Look at Instruction Set Architectures**
# Examines the design and formats of CPU instructions.
#
# #### **Introduction**
#
# #### **Instruction Formats**
#
# #### **Design Decisions for Instruction Sets**
#
# #### **Little Versus Big Endian**
#
# #### **Internal Storage**#### CPU: Stacks Versus Registers
# - The CPU utilizes stacks and registers for storing and managing data efficiently. $E=mc^2$
#
# #### Number of Operands and Instruction Length
# - This concept focuses on the relationship between the number of operands in an instruction and its length. $F=ma$
#
# #### Expanding Opcodes
# - Discusses how opcodes can be expanded to accommodate a larger range of instructions. $c = \sqrt{a^2 + b^2}$
#
# #### Instruction Types
# - Various types of instructions exist in CPU architectures.
#
# #### Data Movement
# - Instructions related to transferring data between memory locations.
#
# #### Arithmetic Operations
# - Instructions for performing mathematical computations.
#
# #### Boolean Logic Instructions
# - Instructions for logical operations like AND, OR, and NOT.
#
# #### Bit Manipulation Instructions
# - Instructions for manipulating individual bits within data.
#
# #### Input/Output Instructions
# - Instructions for interacting with input and output devices.
#
# #### Instructions for Transfer of Control
# - Instructions for altering program flow.
#
# #### Special-Purpose Instructions
# - Instructions with specific functions tailored for unique tasks.
#
# #### Instruction Set Orthogonality
# - The degree to which instructions can be combined in a variety of ways.
#
# #### Addressing
# - Methods for specifying memory addresses in instructions.
#
# #### Data Types
# - Different types of data that can be stored and manipulated in memory.
#
# #### Address Modes
# - Various ways of addressing memory locations.
#
# #### Instruction Pipelining
# - Technique for improving CPU performance by overlapping instruction execution.
#
# #### Real-World Examples of ISAs
# - Examples of different Instruction Set Architectures in use.
#
# #### Intel
# - ISAs developed by Intel for their processors.
#
# #### MIPS
# - An ISA commonly used in embedded systems and academic settings.
#
# #### Java Virtual Machine
# - The ISA used by the Java programming language for platform independence.
#
# #### ARM37
# - A specific version of the ARM architecture used in embedded and mobile devices.
#
# #### Chapter Summary
# - A recap of the key points covered in the chapter.
#
# #### Memory
# - Memory management in computer systems.
#
# #### Introduction
# - Basic understanding of memory structures and functions.
#
# #### Types of Memory
# - Various types of memory used in computer systems.
#
# #### The Memory Hierarchy
# - Organizing memory into levels based on speed and size for efficiency.
#
# #### Locality of Reference
# - Principle that memory access tends to be localized in specific regions.
#
# #### Cache Memory
# - High-speed memory for storing frequently accessed data.
#
# #### Cache Mapping Schemes
# - Techniques for mapping memory blocks to cache locations.
#
# #### Replacement Policies
# - Algorithms for determining which data to replace in the cache.
#
# #### Effective Access Time and Hit Ratio
# - Metrics for evaluating cache performance.
#
# #### When Does Caching
# - Incomplete heading provided.#### Cache Write Policies
# - **Write-Through:** Data is written to both cache and main memory simultaneously.
# - **Write-Back:** Data is written only to the cache initially, and then to main memory when necessary.
#
# #### Instruction and Data Caches
# - Caches that store instructions and data separately to improve performance.
#
# #### Levels of Cache
# - **L1 Cache:** Closest to the CPU, fastest but smallest.
# - **L2 Cache:** Slower than L1 but larger in size.
# - **L3 Cache:** Largest and slower compared to L1 and L2, shared among multiple cores.
#
# #### Virtual Memory
# - Using disk space as an extension of physical memory via address translation.
#
# #### Paging
# - Dividing physical memory into fixed-sized blocks called pages.
#
# #### Advantages of Paging and Virtual Memory
# - Allows for larger virtual memory space, better memory management, and separation of logical and physical memory.
#
# #### Segmentation
# - Dividing memory based on regions or segments.
#
# #### Real-World Examples of Memory Management
# - Applying memory management concepts to practical scenarios.
#
# #### I/O and Performance
# - Input/output operations impact system performance.
#
# #### Amdahl’s Law
# - States the potential performance improvement with parallel processing.
#
# #### Disk Technology
# - Rigid disk drives (HDDs) and solid-state drives (SSDs) are common storage technologies.
#
# #### Optical Disks
# - CD-ROMs are optical discs used for data storage.
#
# #### Character I/O Versus Block I/O
# - Difference between handling individual characters and data blocks in I/O operations.
#
# #### Data Transmission Modes
# - Parallel transmission sends multiple bits simultaneously, whereas serial transmission sends one bit at a time.
#
# #### Further Reading
# - Additional resources to deepen understanding.
# #### DVD
#
# A Digital Versatile Disc (DVD) is a type of optical disc storage media used for storing digital data.
#
# #### Blue-Violet Laser Discs
#
# Blue-Violet Laser Discs use a shorter wavelength laser to increase data storage capacity on optical discs.
#
# #### Optical Disk Recording Methods
#
# Various methods such as write-once, read-many (WORM) and rewritable technologies are used for recording data on optical discs.
#
# #### LTO: Linear Tape Open
#
# Linear Tape Open (LTO) is a magnetic tape storage technology known for high capacity and durability.
#
# #### RAID Level 0
#
# RAID Level 0, also known as striping, distributes data across multiple drives to enhance performance.
#
# #### RAID Level 1
#
# RAID Level 1, also known as mirroring, involves duplicating data across multiple drives for redundancy.
#
# #### RAID Level 5
#
# RAID Level 5 uses striping with distributed parity to achieve both performance and data protection.
#
# #### Virtual Machines
#
# Virtual Machines create simulated environments that mimic physical computing hardware, enabling multiple operating systems to run on a single machine.
#
# #### Assemblers and Assembly
#
# Assemblers convert low-level assembly code to machine code, facilitating program execution.
#
# #### Java: All of the Above
#
# Java is a versatile programming language that combines features of assemblers, compilers, interpreters, and link editors.#### Alternative Architectures
#
# - **RISC Machines**: Reduced Instruction Set Computing focuses on simplicity and efficiency.
# - **Flynn's Taxonomy**: Classifies computer architectures based on instruction and data streams.
# - **Parallel and Multiprocessor Architectures**: Includes superscalar, VLIW, vector processors, interconnection networks, shared memory multiprocessors, and distributed computing.
# - **Alternative Parallel Processing Approaches**: Dataflow computing, neural networks, systolic arrays.
# - **Quantum Computing**: Utilizes quantum-mechanical phenomena for computation.
#
# #### Topics in Embedded Systems
#
# - **Embedded Hardware**: Off-the-shelf, configurable, and custom-designed hardware.
# - **Embedded Software**: Memory organization and operating systems tailored for embedded systems.### Systems
# - **Embedded Systems Software Development**
#
# ### 10.3.3 - Embedded Systems Software Development
# $ \text{Chapter Summary} $
