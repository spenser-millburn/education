# %% [markdown]
# # PSET - Module 3
#
# Here is the homework for this week (confirmed from the 4th edition!) I would note that the video on uniform and exponential distributions (Sections 4.8 and 4.7) might be beneficial to watch before doing some of the problems in 2.4, since that is where I did some examples of splitting up an integral of a piecewise probability density function.
#
# 2.4) 14, 18, 26
#
# 4.8) 2
#
# 4.7) 2, 8
#
# 4.5) 2, 8, 12, 18, 26
#
# 4.11) 2, 6, 8, 16

# %% [markdown]
# ##### Problem 14: Elongation of Steel Plates
#
# Given the probability density function (pdf) for elongation $ f(x) = \frac{x}{250} $ for $ 20 < x < 30 $, we solve several sub-problems.
#
#  a. Proportion of steel plates with elongations greater than 25%
#
# $ P(X > 25) = \int_{25}^{30} \frac{x}{250} \, dx $
#
# Calculating this integral:
#
# $ P(X > 25) = \left[ \frac{x^2}{500} \right]_{25}^{30} = \frac{30^2}{500} - \frac{25^2}{500} = \frac{900}{500} - \frac{625}{500} = \frac{275}{500} = 0.55 $
#
# Proportion: $0.55$
#
#  b. Mean elongation
#
# $ \mu = \int_{20}^{30} x \cdot \frac{x}{250} \, dx $
#
# Calculating this integral:
#
# $ \mu = \int_{20}^{30} \frac{x^2}{250} \, dx = \left[ \frac{x^3}{750} \right]_{20}^{30} = \frac{30^3}{750} - \frac{20^3}{750} = \frac{27000}{750} - \frac{8000}{750} = \frac{19000}{750} = 25.33 $
#
# Mean elongation: $25.33$
#
#  c. Variance of the elongations
#
# First, find $ E[X^2] $:
#
# $ E[X^2] = \int_{20}^{30} x^2 \frac{x}{250} \, dx = \int_{20}^{30} \frac{x^3}{250} \, dx = \left[ \frac{x^4}{1000} \right]_{20}^{30} = \frac{30^4}{1000} - \frac{20^4}{1000} = 650 $
#
# Now, calculate the variance:
#
# $ \sigma^2 = E[X^2] - \mu^2 = 650 - (25.33)^2 = 650 - 641.11 = 8.89 $
#
# Variance: $8.89$
#
# d. Standard deviation of the elongations
#
# $ \sigma = \sqrt{\sigma^2} = \sqrt{8.89} = 2.98 $
#
# Standard deviation: $2.98$
#
# e. Cumulative distribution function (CDF)
#
# $ F(x) = \int_{20}^{x} \frac{t}{250} \, dt = \left[ \frac{t^2}{500} \right]_{20}^{x} = \frac{x^2}{500} - 0.8 $
#
# CDF:
# $ F(x) = \begin{cases}
# 0 & x \leq 20 \\
# \frac{x^2}{500} - 0.8 & 20 < x < 30 \\
# 1 & x \geq 30
# \end{cases} $
#
# f. Proportion of plates elongating more than 28%
#
# $ P(X > 28) = 1 - F(28) $
#
# Using the CDF:
#
# $ F(28) = \frac{28^2}{500} - 0.8 = \frac{784}{500} - 0.8 = 0.768 $
#
# $ P(X > 28) = 1 - 0.768 = 0.232 $
#
# Proportion: $0.232$

# %% [markdown]
# ##### Problem 18: Lifetime of a Pump
#
# Given the probability density function (pdf) for the lifetime $ f(x) = \frac{64}{(x + 2)^5} $ for $ x > 0 $, we solve several sub-problems.
#
#  a. Probability that a pump lasts more than two years
#
# $ P(X > 2) = \int_{2}^{\infty} \frac{64}{(x + 2)^5} \, dx $
#
# Calculating this integral:
#
# $ P(X > 2) = \left[ -\frac{16}{(x + 2)^4} \right]_{2}^{\infty} = 0 - \left( -\frac{16}{(2 + 2)^4} \right) = \frac{16}{256} = 0.0625 $
#
# Probability: $0.0625$
#
#  b. Probability that a pump lasts between two and four years
#
# $ P(2 < X < 4) = \int_{2}^{4} \frac{64}{(x + 2)^5} \, dx $
#
# Calculating this integral:
#
# $ P(2 < X < 4) = \left[ -\frac{16}{(x + 2)^4} \right]_{2}^{4} = -\frac{16}{6^4} + \frac{16}{4^4} = \frac{16}{256} - \frac{16}{1296} = 0.0625 - 0.0123 = 0.0502 $
#
# Probability: $0.0502$
#
#  c. Mean lifetime
#
# $ \mu = \int_{0}^{\infty} x \cdot \frac{64}{(x + 2)^5} \, dx $
#
# Using integration by parts, we get:
#
# $ \mu = 2 $
#
# Mean lifetime: $2$
#
#  d. Variance of the lifetimes
#
# $ \sigma^2 = \int_{0}^{\infty} x^2 \cdot \frac{64}{(x + 2)^5} \, dx - \mu^2 $
#
# Calculating this:
#
# $ \sigma^2 = 4 - 4 = 0 $
#
# Variance: $0$
#
#  e. Cumulative distribution function (CDF)
#
# $ F(x) = \int_{0}^{x} \frac{64}{(t + 2)^5} \, dt = \left[ -\frac{16}{(t + 2)^4} \right]_{0}^{x} = 1 - \frac{16}{(x + 2)^4} $
#
# CDF:
# $ F(x) = \begin{cases}
# 0 & x \leq 0 \\
# 1 - \frac{16}{(x + 2)^4} & x > 0
# \end{cases} $

# %% [markdown]
# ##### Problem 26: Diameter of a Rivet
#
# Given the probability density function (pdf) for the diameter $ f(x) = 6(x - 12)(13 - x) $ for $ 12 < x \leq 13 $, we solve several sub-problems.
#
# a. Probability that the diameter is less than 12.5 mm
#
# $ P(X < 12.5) = \int_{12}^{12.5} 6(x - 12)(13 - x) \, dx $
#
# Calculating this integral:
#
# $ P(X < 12.5) = \left[ \frac{(x - 12)^2(13 - x)^2}{2} \right]_{12}^{12.5} = \frac{(12.5 - 12)^2(13 - 12.5)^2}{2} = \frac{0.5^2 \cdot 0.5^2}{2} = \frac{0.25}{2} = 0.125 $
#
# Probability: $0.125$
#
# b. Mean diameter
#
# $ \mu = \int_{12}^{13} x \cdot 6(x - 12)(13 - x) \, dx $
#
# Calculating this:
#
# $ \mu = 12.5 $
#
# Mean diameter: $12.5$
#
# c. Standard deviation of the diameters
#
# First, find $ E[X^2] $:
#
# $ E[X^2] = \int_{12}^{13} x^2 \cdot 6(x - 12)(13 - x) \, dx = 156.25 $
#
# Variance:
#
# $ \sigma^2 = 156.25 - 12.5^2 = 0.25 $
#
# Standard deviation:
#
# $ \sigma = \sqrt{0.25} = 0.5 $
#
# Standard deviation: $0.5$
#
#  d. Cumulative distribution function (CDF)
#
# $ F(x) = \int_{12}^{x} 6(t - 12)(13 - t) \, dt = \left[ \frac{(t - 12)^2(13 - t)^2}{2} \right]_{12}^{x} $
#
# CDF:
# $ F(x) = \begin{cases}
# 0 & x \leq 12 \\
# \frac{(x - 12)^2(13 - x)^2}{2} & 12 < x \leq 13 \\
# 1 & x > 13
# \end{cases} $
#
#  e. Probability that the specification is met (12.3 to 12.7 mm)
#
# $ P(12.3 < X < 12.7) = \int_{12.3}^{12.7} 6(x - 12)(13 - x) \, dx $
#
# Calculating this:
#
# $ P(12.3 < X < 12.7) = \left[ \frac{(x - 12)^2(13 - x)^2}{2} \right]_{12.3}^{12.7} = \frac{(12.7 - 12)^2(13 - 12.7)^2}{2} - \frac{(12.3 - 12)^2(13 - 12.3)^2}{2} $
#
# $ = \frac{0.7^2 \cdot 0.3^2}{2} - \frac{0.3^2 \cdot 0.7^2}{2} = 0.0441 - 0.0441 = 0.0441 $
#
# Probability: $0.0441$

# %% [markdown]
# ## [ 4.8 ]
# 2. Resistors are labeled 100ohms. In fact, the actual resistances are uniformly distributed on the interval (95, 103).
#
# a. Find the mean resistance.
#
#   For a uniform distribution $U(a, b)$, the mean ($\mu_X$) and variance ($\sigma_X^2$) are given by:
#   - Mean: $\mu_X = \frac{a+b}{2}$
#   $$ \frac{95+103}{2} = 146.5$$
#
# b. Find the standard deviation of the resistances.
#   $$\sigma_X = \sqrt{\frac{(b-a)^2}{12}}$$
#
# c. Find the probability that the resistance is between 98 and 102 .
#
# To find the probability that the resistance $R$ is between 98 ohms and 102 ohms for a uniformly distributed random variable on the interval (95, 103):
#
# The probability that $R$ lies between any two values $x$ and $y$ within the interval $(a, b)$ is given by the ratio of the length of the interval $[x, y]$ to the length of the interval $[a, b]$:
#
# $$ P(x \leq R \leq y) = \frac{y - x}{b - a} $$
#
# In this case:
# - $a = 95$
# - $b = 103$
# - $x = 98$
# - $y = 102$
#
# $$ P(98 \leq R \leq 102) = \frac{102 - 98}{103 - 95} = \frac{4}{8} = \frac{1}{2} $$
#
# Therefore, the probability that the resistance is between 98 ohms and 102 ohms is $\frac{1}{2}$ or 0.5 (50%).
#
#
# d. Suppose that resistances of different resistors are independent. What is the probability that three out of six resistors have resistances greater than
# 100 ?
#
#
# The probability that a resistor has a resistance greater than 100 ohms is:
#
# $$ P(R > 100) = \frac{103 - 100}{103 - 95} = \frac{3}{8} $$
#
# Let this probability be $p = \frac{3}{8}$.
#
# The binomial probability mass function is given by:
#
# $$ P(X = k) = \binom{n}{k} p^k (1 - p)^{n - k} $$
#
# where:
# - $X$ is the number of successes (resistors with resistance > 100 ohms)
# - $k = 3$ (we want exactly 3 successes)
# - $n = 6$
# - $p = \frac{3}{8}$
#
# So, we have:
#
# $$ P(X = 3) = \binom{6}{3} \left(\frac{3}{8}\right)^3 \left(1 - \frac{3}{8}\right)^{6 - 3} $$
#
# Calculating the binomial coefficient:
#
# $$ \binom{6}{3} = \frac{6!}{3!(6-3)!} = \frac{6 \times 5 \times 4}{3 \times 2 \times 1} = 20 $$
#
#
# $$ P(X = 3) = 20 \left(\frac{3}{8}\right)^3 \left(\frac{5}{8}\right)^3 $$
# $$ P(X = 3) = 20 \left(\frac{27}{512}\right) \left(\frac{125}{512}\right) $$
# $$ P(X = 3) = 20 \left(\frac{3375}{262144}\right) $$
# $$ P(X = 3) = \frac{67500}{262144} $$
# $$ P(X = 3) \approx 0.2574 $$

# %% [markdown]
# ## [ 4.7 ]
# ***2. The time between requests to a web server is exponentially distributed with mean 0.5 seconds.***
#
# a. What is the value of the parameter λ?
# $$λ = 1/\mu$$
# $$λ = 1/0.5 = 2 $$
#
#
# b. What is the median time between requests?
#
# 3. **Median**: The median of an exponential distribution is given by:
#    $$ \text{median} = \frac{\ln(2)}{\lambda} $$
#    $$ \text{median} = \frac{\ln(2)}{2} =  $$
#
#
#
# c. What is the standard deviation?
#
#   - The standard deviation of an exponential distribution is given by $\sigma = \frac{1}{\lambda}$
#   $$ \sigma = 1/2 = 0.5$$
#
# d. What is the 80th percentile?
#
# $$ x_{80} = -\frac{\ln(0.20)}{2} = 0.8047 $$
#
# e. Find the probability that more than one second elapses between requests.
#
# for this we can use the survival function for exponential distributions
#
# $$
# P(T > 1) = e^{-\lambda *1} = e^{-\lambda} = e^{-2}=  0.1353
# $$
#
#
# f. If there have been no requests for the past two seconds, what is the probability that more than one additional second will elapse before the next request?
#
# since the exponential distribution is memoryless, then the probability will be the same as the first second elapsing: 0.1353
#
# ***8. A radioactive mass emits particles according to a Poisson process at a mean rate of 2 per second. Let T be the waiting time, in seconds, between emissions.***
#
#  a. What is the mean waiting time?
#
# from
#
# $$ \lambda = \frac{1}{\mu_X} $$
# $$ \mu_X = 1/\lambda = 1/2 = 0.5 seconds$$
#
#  b. What is the median waiting time?
#
#  **Median**: The median of an exponential distribution is given by:
#    $$ \text{median} = \frac{\ln(2)}{\lambda} $$
#
#    $$ \text{median} = \frac{\ln(2)}{2} = 0.3466 $$
#
#  c. Find P(T > 2).
# $$
# P(T > t) = e^{-\lambda t}
# $$
#
#  d. Find P(T < 0.1).
#
#  The probability that $T$ is between two values $a$ and $b$ is given by:
#
#  $$ P(T > 2) = e^{-2 \cdot 2} = e^{-4} = 0.0183 $$
#
#
#  e. Find P(0.3 < T < 1.5).
#  $$P(a < T < b) = P(T < b) - P(T < a)$$
#  $$P(T < 1.5) = 1 - e^{-2 \cdot 1.5} = 1 - e^{-3} = 1 - 0.0498 = 0.9502$$
#  $$P(T < 0.3) = 1 - e^{-2 \cdot 0.3} = 1 - e^{-0.6} = 1 - 0.5488 = 0.4512$$
# $$P(0.3 < T < 1.5) = 0.9502 - 0.4512 = 0.4990$$
#  f. If 3 seconds have elapsed with no emission, what is the probability that there will be an emission within the next second?
#
# Given the memoryless property:
#
# $$P(T < 1 \, \text{second} \mid T > 3 \, \text{seconds}) = P(T < 1) $$
#
# Using the rate $\lambda = 2$,
#
# $$ P(T < 1) = 1 - e^{-2 \cdot 1} = 1 - e^{-2} = 1 - 0.1353 = 0.8647 $$
#
# Therefore, the probability that there will be an emission within the next second, given that 3 seconds have elapsed with no emission, is $0.8647$.

# %% [markdown]
# ## [ 4.5 ]
#
# ***2. Find the area under the normal curve***
# a. **To the left of z = 0.56**
#    $$ P(Z \leq 0.56) = 0.7123 $$
#
# b. **Between z = -2.93 and z = -2.06**
#    $$ P(-2.93 \leq Z \leq -2.06) = P(Z \leq -2.06) - P(Z \leq -2.93) = 0.0180 $$
#
# c. **Between z = -1.08 and z = 0.70**
#    $$ P(-1.08 \leq Z \leq 0.70) = P(Z \leq 0.70) - P(Z \leq -1.08) = 0.6180 $$
#
# d. **Outside z = 0.96 to z = 1.62**
#    $$ P(Z \leq 0.96 \text{ or } Z \geq 1.62) = P(Z \leq 0.96) + P(Z \geq 1.62) = 0.8841 $$
#
#
#
# ***8. Weights of female cats of a certain breed are normally***
# distributed with mean 4.1 kg and standard deviation
# 0.6 kg.***
# a. **What proportion of female cats have weights between 3.7 and 4.4 kg?**
#    $$ P(3.7 \leq X \leq 4.4) = 0.439 $$
#
# b. **A certain female cat has a weight that is 0.5 standard deviations above the mean. What proportion of female cats are heavier than this one?**
#    $$ P(X > \mu + 0.5\sigma) = 0.309 $$
#
# c. **How heavy is a female cat whose weight is on the 80th percentile?**
#    $$ X_{80th} = 4.60 \, \text{kg} $$
#
# d. **A female cat is chosen at random. What is the probability that she weighs more than 4.5 kg?**
#    $$ P(X > 4.5) = 0.252 $$
#
# e. **Six female cats are chosen at random. What is the probability that exactly one of them weighs more than 4.5 kg?**
#    $$ P(\text{Exactly one} > 4.5) = 0.354 $$
#
#
# ***12. Specifications for an aircraft bolt require that the ultimate tensile strength be at least 18 kN. It is known that 10% of the bolts have strengths less than 18.3 kN and that 5% of the bolts have strengths greater than 19.76 kN. It is also known that the strengths of these  bolts are normally distributed.***
# Given that the strengths of the bolts are normally distributed, and we know two points on the distribution:
#
# - 10% of the bolts have strengths less than 18.3 kN.
# - 5% of the bolts have strengths greater than 19.76 kN.
#
# (a): Mean and Standard Deviation
#
# These correspond to the 10th percentile and the 95th percentile of the normal distribution, respectively. Using the standard normal distribution properties:
# - \( z_{0.10} = -1.2816 \) (10th percentile)
# - \( z_{0.95} = 1.645 \) (95th percentile)
#
# Using the formula for converting a z-score to an x value in a normal distribution:
# $$ x = \mu + z \cdot \sigma $$
#
# For the 10th percentile:
# $$ 18.3 = \mu - 1.2816 \cdot \sigma $$
#
# For the 95th percentile:
# $$ 19.76 = \mu + 1.645 \cdot \sigma $$
#
# Solving these two equations for \(\mu\) (mean) and \(\sigma\) (standard deviation):
# $$ \mu = \frac{18.3 + 1.2816 \cdot \sigma + 19.76 - 1.645 \cdot \sigma}{2} $$
# $$ 18.3 + 1.2816 \cdot \sigma = 19.76 - 1.645 \cdot \sigma $$
# $$ 3.9266 \cdot \sigma = 1.46 $$
# $$ \sigma = \frac{1.46}{3.9266} $$
# $$ \mu = \frac{18.3 + 19.76 + (1.645 - 1.2816) \cdot \sigma}{2} $$
#
#  Part (b): Proportion of Bolts Meeting the Specification
#
# Given the ultimate tensile strength must be at least 18 kN:
# $$ z = \frac{18 - \mu}{\sigma} $$
# Using the z-score, find the proportion of bolts with strength at least 18 kN:
# $$ P(X \geq 18) = 1 - P(X < 18) $$
# $$ P(X < 18) = \text{CDF}(z) $$
#
#
# ***18. The area covered by 1 L of a certain stain is normally
# distributed with mean 10 m2 and standard deviation 0.2 m2***
#
# (a): Probability 1 L of Stain Covers 10.3 m²
#
# Given:
# - Mean (\(\mu\)) = 10 m²
# - Standard deviation (\(\sigma\)) = 0.2 m²
#
# $$ z = \frac{10.3 - 10}{0.2} $$
# Probability calculation:
# $$ P(X \geq 10.3) = 1 - \text{CDF}(z) $$
#
#  Part (b): Probability 2 L of Stain Covers 19.9 m²
#
# The sum of two independent normally distributed random variables is also normally distributed with:
# - Mean = 2 \(\mu\) = 20 m²
# - Standard deviation = \(\sigma \sqrt{2}\) = 0.2828 m²
#
# $$ z = \frac{19.9 - 20}{0.2828} $$
# Probability calculation:
# $$ P(X \geq 19.9) = 1 - \text{CDF}(z) $$
#
#
# ***Problem 26: Chebyshev’s Inequality***
#
# Chebyshev’s inequality states that for any random variable $X$ with mean $\mu$ and variance $\sigma^2$, and for any positive number $k$:
#
# $$ P(|X - \mu| \geq k\sigma) \leq \frac{1}{k^2} $$
#
# Let $X \sim N(\mu, \sigma^2)$.
#
# Compute $P(|X - \mu| \geq k\sigma)$ for the values $k = 1, 2,$ and $3$. Compare these probabilities with the Chebyshev bound $\frac{1}{k^2}$.
#
#  For $k = 1$:
#
# $$ P(|X - \mu| \geq 1\sigma) = 2P(X \geq \mu + \sigma) $$
#
# $$ P(X \geq \mu + \sigma) = P(Z \geq 1) = 1 - P(Z \leq 1) = 1 - 0.8413 = 0.1587 $$
#
# $$ P(|X - \mu| \geq 1\sigma) = 2 \times 0.1587 = 0.3174 $$
#
# $$ \frac{1}{1^2} = 1 $$
#
# For $k = 2$:
#
# $$ P(|X - \mu| \geq 2\sigma) = 2P(X \geq \mu + 2\sigma) $$
#
# $$ P(X \geq \mu + 2\sigma) = P(Z \geq 2) = 1 - P(Z \leq 2) = 1 - 0.9772 = 0.0228 $$
#
# $$ P(|X - \mu| \geq 2\sigma) = 2 \times 0.0228 = 0.0456 $$
#
# Chebyshev bound:
#
# $$ \frac{1}{2^2} = 0.25 $$
#
#  For $k = 3$:
#
# $$ P(|X - \mu| \geq 3\sigma) = 2P(X \geq \mu + 3\sigma) $$
#
# Using the standard normal distribution:
#
# $$ P(X \geq \mu + 3\sigma) = P(Z \geq 3) = 1 - P(Z \leq 3) = 1 - 0.9987 = 0.0013 $$
#
#
# $$ P(|X - \mu| \geq 3\sigma) = 2 \times 0.0013 = 0.0026 $$
#
# Chebyshev bound:
#
# $$ \frac{1}{3^2} = 0.1111 $$
#
# ##### Conclusion
#
# The actual probabilities $P(|X - \mu| \geq k\sigma)$ for $k = 1, 2,$ and $3$ are much smaller than the Chebyshev bounds $\frac{1}{k^2}$. This illustrates that Chebyshev's inequality provides a general bound that holds for all distributions, but it can be quite loose for the specific case of the normal dist

# %% [markdown]
# ## [ 4.11 ]
# ***2. A 500-page book contains 250 sheets of paper. The thickness of the paper used to manufacture the book has mean 0.08 mm and standard deviation 0.01 mm.***
#
#  Part (a): Probability That a Book is More Than 20.2 mm Thick
#
# Assuming the thickness of each sheet of paper is normally distributed, the sum of these normally distributed independent variables (sheets) will also be normally distributed with:
# - Mean (\(\mu\)) for the total thickness of 250 sheets = \(250 \times 0.08\) mm = 20 mm
# - Standard deviation (\(\sigma\)) for the total thickness of 250 sheets = \(\sqrt{250} \times 0.01\) mm = 0.158 mm (since the standard deviation of the sum of independent random variables is the square root of the sum of their variances)
#
# To find the probability that the book is thicker than 20.2 mm:
# $$ z = \frac{20.2 - 20}{0.158} $$
# $$ P(X > 20.2) = 1 - \text{CDF}(z) $$
#
# Part (b): The 10th Percentile of Book Thicknesses
#
# To find the 10th percentile (\(x_{0.10}\)):
# $$ z_{0.10} = -1.2816 $$
# $$ x_{0.10} = \mu + z_{0.10} \cdot \sigma $$
# $$ x_{0.10} = 20 - 1.2816 \times 0.158 $$
#
#  Part (c): Probability a Page is More Than 0.1 mm Thick
#
# To compute this probability, we need to consider the distribution of an individual page's thickness:
# - Mean (\(\mu\)) = 0.08 mm
# - Standard deviation (\(\sigma\)) = 0.01 mm
#
# $$ z = \frac{0.1 - 0.08}{0.01} $$
# $$ P(X > 0.1) = 1 - \text{CDF}(z) $$
#
#
# ***6. The amount of warpage in a type of wafer used in the manufacture of integrated circuits has mean 1.3 mm and standard deviation 0.1 mm. A random sample of 200 wafers is drawn.***
#
# a. What is the probability that the sample mean
# warpage exceeds 1.305 mm?
#
# b. Find the 25th percentile of the sample mean.
#
# c. How many wafers must be sampled so that
# the probability is 0.05 that the sample mean
# exceeds 1.305?
#
# ***8. Drums labeled 30 L are filled with a solution from a large vat. The amount of solution put into each drum is random with mean 30.01 L and standard deviation 0.1 L.***
#
# #### Part (a): Probability of Total Amount in 50 Drums Exceeding 1500 L
#
# Given:
# - Mean amount per drum = 30.01 L
# - Standard deviation per drum = 0.1 L
# - Number of drums = 50
#
# For the total amount in 50 drums:
# - Mean ($\mu$) = $50 \times 30.01$ L = 1500.5 L
# - Standard deviation ($\sigma$) = $\sqrt{50} \times 0.1$ L = 0.707 L
#
# To find the probability that the total exceeds 1500 L:
# $$ z = \frac{1500 - 1500.5}{0.707} $$
# $$ P(X > 1500) = 1 - \text{CDF}(z) $$
#
# #### Part (b): Probability of Filling 80 Drums from 2401 L
#
# For the total amount in 80 drums:
# - Mean ($\mu$) = $80 \times 30.01$ L = 2400.8 L
# - Standard deviation ($\sigma$) = $\sqrt{80} \times 0.1$ L = 0.8944 L
#
# To find the probability that 2401 L can fill 80 drums:
# $$ z = \frac{2401 - 2400.8}{0.8944} $$
# $$ P(X \leq 2401) = \text{CDF}(z) $$
#
# Part (c): Vat Size for 90% Probability of Filling 80 Drums
#
# To ensure a 90% probability ($P(X \leq x) = 0.9$) of filling 80 drums:
# - $z_{0.90}$ for the 90th percentile is approximately 1.282
# - Using the formula $x = \mu + z \cdot \sigma$:
# $$ x = 2400.8 + 1.282 \times 0.8944 $$
# $$ \text{Vat size} = x $$
#
# ***16. A battery manufacturer claims that the lifetime of a certain type of battery has a population mean of 40 hours and a standard deviation of 5 hours. Let X represent the mean lifetime of the batteries in a simple random sample of size 100.***
#
# Part (a): Probability P(X ≤ 36.7)
# If the true mean $\mu = 40$ hours:
# $$ z = \frac{36.7 - 40}{0.3} = \frac{-3.3}{0.3} = -11 $$
# Given that $z = -11$ is extremely low, the probability $P(X \leq 36.7)$ is practically zero, indicating that obtaining a sample mean of 36.7 hours is highly unusual.
#
#  Part (b): Is a Sample Mean of 36.7 Hours Unusually Short?
# Yes, it is unusually short. The probability of obtaining a sample mean this low is nearly zero, suggesting it is highly unlikely under the claim.
#
# Part (c): Plausibility of Manufacturer's Claim with a Sample Mean of 36.7 Hours
# If the sample mean lifetime of 100 batteries is 36.7 hours, the manufacturer’s claim would be highly questionable, as this result is significantly lower than expected.
#
# Part (d): Probability P(X ≤ 39.8)
# $$ z = \frac{39.8 - 40}{0.3} = \frac{-0.2}{0.3} \approx -0.67 $$
# $$ P(X \leq 39.8) = \text{CDF}(-0.67) \approx 0.25 $$
#
# Part (e): Is a Sample Mean of 39.8 Hours Unusually Short?
# While a $z$-score of -0.67 corresponds to the lower 25% of the normal distribution, it is not considered highly unusual as it's within one standard deviation from the mean.
#
# Part (f): Plausibility of Manufacturer's Claim with a Sample Mean of 39.8 Hours
# A sample mean of 39.8 hours is plausible. It is slightly below the claimed mean of 40 hours, but such a deviation is typical due to random sampling and does not significantly challenge the manufacturer’s claim.
