# %% [markdown]
# ## The Poisson Process

# %%
import matplotlib.pyplot as plt
import networkx as nx

# Create a directed graph
G = nx.DiGraph()

max_state = 5 
for i in range(max_state):
    G.add_node(i)
    G.add_edge(i, i + 1, label='λ')

G.add_node(max_state)

# Position nodes in a line
pos = {i: (i, 1) for i in range(max_state + 1)}

plt.figure(figsize=(10, 4))
nx.draw(G, pos, with_labels=True, node_color='skyblue', node_size=2000, arrowstyle='-|>', arrowsize=20)
nx.draw_networkx_edge_labels(G, pos, edge_labels={(u, v): d['label'] for u, v, d in G.edges(data=True)})

plt.title("Transition Graph of the Poisson Process")
plt.axis('off')  
plt.show()

# %% [markdown]
# ### Write out the jump rate matrix for the poisson process.
# $$
# Q = \begin{bmatrix}
# -\lambda & \lambda & 0 & 0 & \cdots \\
# 0 & -\lambda & \lambda & 0 & \cdots \\
# 0 & 0 & -\lambda & \lambda & \cdots \\
# 0 & 0 & 0 & -\lambda & \cdots \\
# \vdots & \vdots & \vdots & \vdots & \ddots \\
# \end{bmatrix}
# $$

# %% [markdown]
# ###  Explain the three assumptions that we make when we model a counting process using a poisson process.
#
# 1. **Independence of Increments**:
#    The events in non-overlapping intervals are independent.
#
# 2. **Stationarity of Increments**:
#    The number of events in any interval of fixed length$t$ only depends on the length $t$ and not on the position of the interval on the time axis. Thus,$P(N(t) = k) = \frac{(\lambda t)^k e^{-\lambda t}}{k!}$, where $\lambda$ is the rate parameter of the process.
#
# 3. **No Simultaneous Events**:
#    The probability of two or more events occurring simultaneously is zero. This is reflected in the Poisson probability formula, where the interval between events typically follows an exponential distribution, which does not allow for zero-length intervals between events.
